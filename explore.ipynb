# %%
import pandas as pd
print("pandas", pd.__version__)
# Out:
# pandas 2.3.3

# %%
from pathlib import Path

# %%
CSV_DIR = Path("/Users/camarenrogers/synthea/output/csv")

# %%
for f in sorted(CSV_DIR.glob("*.csv")):
    print(f.name)
# Out:
# allergies.csv
# careplans.csv
# claims.csv
# claims_transactions.csv
# conditions.csv
# devices.csv
# encounters.csv
# imaging_studies.csv
# immunizations.csv
# medications.csv
# observations.csv
# organizations.csv
# patient_expenses.csv
# patients.csv
# payer_transitions.csv
# payers.csv
# procedures.csv
# providers.csv
# supplies.csv

# %%
patients = pd.read_csv(CSV_DIR / "patients.csv")
encounters = pd.read_csv(CSV_DIR / "encounters.csv")
conditions = pd.read_csv(CSV_DIR / "conditions.csv")
observations = pd.read_csv(CSV_DIR / "observations.csv")
medications = pd.read_csv(CSV_DIR / "medications.csv")

print("patients", patients.shape)
print("encounters", encounters.shape)
print("conditions", conditions.shape)
print("observations", observations.shape)
print("medications", medications.shape)
# Out:
# patients (122, 28)
# encounters (7805, 15)
# conditions (5179, 7)
# observations (107506, 9)
# medications (7452, 13)

# %%
print(patients.columns.tolist())
print()
# Out:
# ['Id', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']

# %%
patients[['Id', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']].head(10)
# Out:
#                                      Id   BIRTHDATE   DEATHDATE          SSN  \
# 0  c4403761-30d1-dc35-8cbf-61a6187ae642  1986-01-04         NaN  999-62-6468
# 1  8ca688c5-0ee2-7b0a-7bcf-0a925a28331a  1974-02-08         NaN  999-82-2236
# 2  a5cd7871-583d-100c-191f-59ef98970d79  1973-10-29         NaN  999-51-9109
# 3  d9cbcb38-dbef-ddf5-798d-bc5c45ee692c  1964-11-02         NaN  999-33-6691
# 4  9d5f45bd-c6c1-31be-6b2b-95c03182c82c  1964-01-22         NaN  999-50-2798
# 5  5df500f7-7209-bce3-01d5-99333a3fda6c  1958-05-09         NaN  999-32-7718
# 6  18326fbc-2ff1-f214-f327-0766b0e1438e  1958-01-18         NaN  999-60-3381
# 7  3b15bfe9-f15d-ea32-8e2e-f7947218019b  1965-01-02  2018-05-26  999-15-7124
# 8  7246d937-b87b-9679-8271-60492ca51c4f  1953-11-20         NaN  999-21-3658
# 9  921257a5-1a46-8950-48da-b26a4629563b  2022-08-16         NaN  999-68-1912
#
#      DRIVERS    PASSPORT PREFIX        FIRST      MIDDLE           LAST  ...  \
# ...

# %%
print("Unique patients in patients.csv:", patients['Id'].nunique())
print("Unique patients in encounters: ", encounters['PATIENT'].nunique())
print("Avg encounters per patient: ",
        round(len(encounters) / patients['Id'].nunique(), 1))
# Out:
# Unique patients in patients.csv: 122
# Unique patients in encounters:  122
# Avg encounters per patient:  64.0

# %%
encounters[["Id", "PATIENT", "START", "DESCRIPTION", "ENCOUNTERCLASS"]].head()
# Out:
#                                      Id                               PATIENT  \
# 0  c4403761-30d1-dc35-d2b7-a92387372a78  c4403761-30d1-dc35-8cbf-61a6187ae642
# 1  c4403761-30d1-dc35-4703-cfcfa192197f  c4403761-30d1-dc35-8cbf-61a6187ae642
# 2  c4403761-30d1-dc35-e57e-ebc12a307474  c4403761-30d1-dc35-8cbf-61a6187ae642
# 3  c4403761-30d1-dc35-5b1d-241434c2e806  c4403761-30d1-dc35-8cbf-61a6187ae642
# 4  c4403761-30d1-dc35-b276-cf8ffbddef67  c4403761-30d1-dc35-8cbf-61a6187ae642
#
#                   START                                 DESCRIPTION  \
# 0  2004-02-28T13:32:20Z  General examination of patient (procedure)
# 1  2005-03-05T13:32:20Z  General examination of patient (procedure)
# 2  2008-03-08T13:32:20Z  General examination of patient (procedure)
# 3  2014-03-15T13:32:20Z  General examination of patient (procedure)
# 4  2017-03-18T13:32:20Z  General examination of patient (procedure)
#
#   ENCOUNTERCLASS
# 0       wellness
# 1       wellness
# 2       wellness
# ...

# %%
print(encounters.columns.tolist())
print()
# Out:
# ['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PROVIDER', 'PAYER', 'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST', 'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE', 'REASONDESCRIPTION']

# %%
pid = patients["Id"].iloc[0]
print("Tracing patient:", pid)
print()
# Out:
# Tracing patient: c4403761-30d1-dc35-8cbf-61a6187ae642

# %%
print('=== Their encounters ===')
display(encounters[encounters["PATIENT"] == pid][["START", "ENCOUNTERCLASS", "DESCRIPTION"]].head(10))
# Out:
# === Their encounters ===
#                   START ENCOUNTERCLASS  \
# 0  2004-02-28T13:32:20Z       wellness
# 1  2005-03-05T13:32:20Z       wellness
# 2  2008-03-08T13:32:20Z       wellness
# 3  2014-03-15T13:32:20Z       wellness
# 4  2017-03-18T13:32:20Z       wellness
# 5  2017-04-01T13:32:20Z     ambulatory
# 6  2017-10-21T15:13:38Z      emergency
# 7  2018-01-01T16:41:38Z     ambulatory
# 8  2018-05-17T13:32:20Z     outpatient
# 9  2020-01-03T16:41:38Z      emergency
#
#                                   DESCRIPTION
# 0  General examination of patient (procedure)
# 1  General examination of patient (procedure)
# 2  General examination of patient (procedure)
# 3  General examination of patient (procedure)
# 4  General examination of patient (procedure)
# 5          Encounter for check up (procedure)
# 6        Emergency room admission (procedure)
# 7          Encounter for check up (procedure)
# 8           Encounter for symptom (procedure)
# ...
